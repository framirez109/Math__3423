# %%
'''
Function Optimization Using ==> scipy.opimize
The Following Minimization Algoriths Are Implemented:
    minimize(method=’Nelder-Mead’)  <=
    minimize(method=’Powell’)       <=
    minimize(method=’CG’)           <=
    minimize(method=’BFGS’)         <=
    minimize(method=’Newton-CG’)    <= Requires The Gradient & Hessian
    minimize(method=’L-BFGS-B’)     <=
    minimize(method=’TNC’)          <= 
    minimize(method=’COBYLA’)       <= 
    minimize(method=’SLSQP’)        <= 
    minimize(method=’trust-constr’) <=
    minimize(method=’dogleg’)       <= Requires The Gradient & Hessian
    minimize(method=’trust-ncg’)    <= Requires The Gradient & Hessian
    minimize(method=’trust-krylov’) <= Requires The Gradient & Hessian
    minimize(method=’trust-exact’)  <= Requires The Gradient & Hessian 
'''

from numpy import array
from scipy.optimize import minimize

a = 5 ;b = 300; c = 10
def f(x): 
    return (a - x[0])**2 + b*(x[1] - x[0]**2)**2 + c

def gradient(x):
    return array([-2*(a - x[0]) - 4.*b*x[0]*(x[1] - x[0]**2), 
                     2*b*(x[1] - x[0]**2)])

def hessian(x):
    return array([[2 - 4*b*x[1] + 12*b*x[0]**2, -4*b*x[0] ], 
                  [-4*b*x[0], 2*b]])

x0 = array([-3.4,3.4])
result = minimize(f, x0, method = 'Newton-CG',
                  jac = gradient, hess = hessian, tol=1.e-7)

print(" ")
print("The Minimum Occurs at (x, y) = (x0, x1) = ", result.x)
print(" ")
print("And The Minimum Value = ", f(result.x))
print(" ")
print("Other Statistics:" ) 
print( result )          
#
# Plot Function: 
#      
from numpy import linspace, meshgrid
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d') 

x = linspace( -1, 1, 20)
y = linspace( -1, 1, 20)
 
x, y = meshgrid(x,y)
z = ( a - x )**2 + b *( y - x**2 )**2 + c

surf = ax.plot_surface(x, y, z, 
       rstride=1, cstride=1, cmap=cm.jet, linewidth=0)
plt.show()
# Out:
#
# The Minimum Occurs at (x, y) = (x0, x1) =  [-1.81630228  3.30327903]
#
# And The Minimum Value =  56.46758859426242
#
# Other Statistics:
#      fun: 56.46758859426242
#      jac: array([2.79301052, 4.52290523])
#  message: 'Warning: Maximum number of iterations has been exceeded.'
#     nfev: 401
#     nhev: 400
#      nit: 400
#     njev: 401
#   status: 1
#  success: False
#        x: array([-1.81630228,  3.30327903])
# <ipython-input-144-fae18088b5b7>:54: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# Values: [-1,1]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did function evaluations of 156.
#
# BFGS
# Using this method did converge. It did not have the same number of iterations(87) as it function evaluations(116).
#
# Powell
# Using this method did not converge. It did not have the same number of iterations(56) as it function evaluations(2031).
#
# Nelder-Mead
# Using this method did not converge. It did not have the same number of iterations(216) as it function evaluations(400).
#
# Trust-constr
# Using this method did converge. It did not have the same number of iterations(144) as it function evaluations(94).
#
#
# SLSQP
# Using this method did converge.It had the same iterations as it did function evaluations of 156.
#
#
# COBYLA
# Using this method did not converge. Maximum number of function evaluations was been exceeded.
#
#
# TNC
# Using this method did not converge. Maximum number of function evaluations was been exceeded.
#
#
# CG
# Using this method did converge. It did not have the same number of iterations(72) as it function evaluations(163).
#
# Dogleg
# Using this method did not converge. It did not have the same number of iterations(72) as it function evaluations(163).
#
# Out of all the algorithms that converged, _____ had the least number of iterations.
#
#
# Values: [-3.4, 3.4]
#
# Newton-CG
# Using this method did not converge. It had the same iterations as it did function evaluations of 400.
#
#
# BFGS
# Using this method did converge. It did not have the same number of iterations as it did function evaluations.
#
# Powell
# Using this method did not converge. Maximum number of function evaluations had been exceeded.
#
# Nelder-Mead
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did function evaluations of 167.
#
#
# SLSQP
# Using this method did converge. It had the same iterations as it did function evaluations of 87.
#
#
# COBYLA
# Using this method did not converge. Maximum number of function evaluations had been exceeded.
#
# TNC
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# CG
# Using this method did converge. It did not have the same number of iterations as it did function evaluations.
#
#
# Dogleg
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
#
# Values: [0,20]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did hessian computations (125).
#
# BFGS
# Using this method did converge. It did not have the same number of iterations(49) as it did function evaluations.
#
#
# Powell
# Using this method did converge. It did not have the same number of iterations(14) as it did function evaluations.
#
# Nelder-Mead
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did hessian computations of 105.
#
#
# SLSQP
# Using this method did converge. It did not have the same number of iterations (85).
#
# COBYLA
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
# TNC
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# CG
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# Dogleg
# Using this method did not converge.
#
# Out
#
# Values: [-10,10]
#
# Newton-CG
# Using this method did not converge. It had the same iterations as it did hessian computations of 400.
#
#
# BFGS
# Using this method did converge. It did not have the same number of iterations (161) as it did function evaluations.
#
#
# Powell
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# Nelder-Mead
# Using this method did not coverge. It did not have the same number of iterations as it did function evaluations.
#
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did hessian computations of 224.
#
#
# SLSQP
# Using this method did converge. It had 81 iterations.
#
#
# COBYLA
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# TNC
# Using this method did not converge. It did not have the same number of iterations as it did function evaluations.
#
#
# CG
# Using this method did converge. It did not have the same number of iterations as it did function evaluations.
#
# Dogleg
# Using this method did not converge.
#
# Values: [5,7]
#
# Newton-CG
# Using this method did converge. It had 85 iterations and 174 function evaluations.
#
# BFGS
# Using this method did converge. It had 28 iterations and 39 function evaluations.
#
# Powell
# Using this method did converge. It had 39 iterations and 1397 iterations.
#
# Nelder-Mead
# Using this method did converge. It had 144 iterations and 276 function evaluations.
#
# Trust-constr
# Using this method did converge. It had the same number of iterations and function evaluations (70).
#
# SLSQP
# Using this method did converge. It had 99 iterations and 139 function evaluations.
#
# COBYLA
# Using this method did not converge. Maximum number of function evaluations has been exceeded.
#
# TNC
# Using this method did not converge. Max. number of function evaluations reached.
#
# CG
# Using this method did converge. It had 79 iterations and 184 function evaluations.
#
# Dogleg
# Using this method did converge. It had 32 iterations and 33 function evaluations.

# %%
'''
Function Optimization Using ==> scipy.opimize
The Following Minimization Algoriths Are Implemented:
    minimize(method=’Nelder-Mead’)  <=
    minimize(method=’Powell’)       <=
    minimize(method=’CG’)           <=
    minimize(method=’BFGS’)         <=
    minimize(method=’Newton-CG’)    <= Requires The Gradient & Hessian
    minimize(method=’L-BFGS-B’)     <=
    minimize(method=’TNC’)          <= 
    minimize(method=’COBYLA’)       <= 
    minimize(method=’SLSQP’)        <= 
    minimize(method=’trust-constr’) <=
    minimize(method=’dogleg’)       <= Requires The Gradient & Hessian
    minimize(method=’trust-ncg’)    <= Requires The Gradient & Hessian
    minimize(method=’trust-krylov’) <= Requires The Gradient & Hessian
    minimize(method=’trust-exact’)  <= Requires The Gradient & Hessian 
'''

from numpy import array
from scipy.optimize import minimize

a = 7 ; b = 5;

def f(x): 
    return (x[0] + 2*x[1] - a)**2 + (2*x[0] + x[1] - b)**2

def gradient(x):
    return array([2*(x[0] + 2*x[1] - a) + 4*(2*x[0] + x[1] - b), 
                4*(x[0] + 2*x[1] - a) + 2*(2*x[0] + x[1] - b)])

def hessian(x):
    return array([[10, 8], 
                  [8,10]])

x0 = array([-500,500])
result = minimize(f, x0, method = 'Dogleg',
                  jac = gradient, hess = hessian, tol=1.e-7)

print(" ")
print("The Minimum Occurs at (x, y) = (x0, x1) = ", result.x)
print(" ")
print("And The Minimum Value = ", f(result.x))
print(" ")
print("Other Statistics:" ) 
print( result )          
#
# Plot Function: 
#      
from numpy import linspace, meshgrid
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d') 

x = linspace( -3, 3, 20)
y = linspace( -3, 3, 20)
 
x, y = meshgrid(x,y)
z = (x + 2*y - a)**2 + (2*x + y - b)**2

surf = ax.plot_surface(x, y, z, 
       rstride=1, cstride=1, cmap=cm.jet, linewidth=0)
plt.show()
# Out:
#
# The Minimum Occurs at (x, y) = (x0, x1) =  [1. 3.]
#
# And The Minimum Value =  4.0389678347315804e-27
#
# Other Statistics:
#      fun: 4.0389678347315804e-27
#     hess: array([[10,  8],
#        [ 8, 10]])
#      jac: array([2.84217094e-13, 2.27373675e-13])
#  message: 'Optimization terminated successfully.'
#     nfev: 11
#     nhev: 10
#      nit: 10
#     njev: 11
#   status: 0
#  success: True
#        x: array([1., 3.])
# <ipython-input-1-ccf64e28b94a>:55: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# Values: [-1,1]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did function evaluations of 2.
#
# BFGS
# Using this method did converge.It had 2 iterations and 3 function evaluations.
#
# Powell
# Using this method did converge. It had 3 iterations and 65 function evaluations.
#
#
# Nelder-Mead
# Using this method did converge. It had 67 iterations and 128 function evaluations.
#
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did function evaluations of 3.
#
#
# SLSQP
# Using this method did converge.It had 3 iterations and 4 function evaluations.
#
#
# COBYLA
# Using this method did converge. Optimization terminated successfully.
#
#
# TNC
# Using this method did converge. It had 3 iterations and 7 function evaluations.
#
#
# CG
# Using this method did converge. It had 1 iterations and 3 function evaluations.
#
# Dogleg
# Using this method did converge. It had 2 iterations and 3 function evaluations.
#
#
# Out of all the algorithms that converged, _____ had the least number of iterations.
#
#
# Values: [-4,8]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did function evaluations of 2.
#
#
# BFGS
# Using this method did converge. It had 3 iterations and 4 function evaluations.
#
#
# Powell
# Using this method did converge. It had 4 iterations and 92 function evaluations.
#
#
# Nelder-Mead
# Using this method did converge. It had 66 iterations and 127 function evaluations.
#
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did function evaluations of 3.
#
#
# SLSQP
# Using this method did converge. It had 2 iterations and 3 function evaluations.
#
#
# COBYLA
# Using this method did converge. Optimization terminated successfully.
#
#
# TNC
# Using this method did converge. It had 2 iterations and 3 function evaluations.
#
#
# CG
# Using this method did converge. It had 3 iterations and 7 function evaluations.
#
#
# Dogleg
# Using this method did converge. It had the same iterations as it did function evaluations of 4.
#
#
# Values: [-7,9]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did function evaluations of 2.
#
#
# BFGS
# Using this method did converge. It had 7 iterations and 8 function evaluations.
#
#
# Powell
# Using this method did converge. It had 4 iterations and 94 function evaluations.
#
#
# Nelder-Mead
# Using this method did converge. It had 74 iterations and 135 function evaluations.
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did function evaluations of 4.
#
#
# SLSQP
# Using this method did converge. It had 5 iterations and 7 function evaluations.
#
#
# COBYLA
# Using this method did converge. Optimization terminated successfully.
#
# TNC
# Using this method did converge. It had 3 iterations and 7 function evaluations.
#
#
# CG
# Using this method did converge. It had 34 iterations and 52 function evaluations.
#
#
# Dogleg
# Using this method did not converge. It had the same iterations as it did function evaluations of 4.
#
#
# Values: [-2,-1]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did function computations of 5.
#
#
# BFGS
# Using this method did converge. It had 8 iterations and 9 function evaluations.
#
#
# Powell
# Using this method did converge. It had 3 iterations and 65 function evaluations.
#
#
# Nelder-Mead
# Using this method did coverge. It had 76 iterations and 144 function evaluations.
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did function computations of 3.
#
# SLSQP
# Using this method did converge. It had 5 iterations and 7 function evaluations.
#
#
# COBYLA
# Using this method did converge. Optimization terminated successfully.
#
# TNC
# Using this method did converge. It had 3 iterations and 7 function evaluations.
#
#
# CG
# Using this method did converge. It had 2 iterations and 5 function evaluations.
#
# Dogleg
# Using this method did converge. It had 3 iterations and 4 function evaluations.
#
#
# Values: [-5,5]
#
# Newton-CG
# Using this method did converge. It had the same iterations as it did function computations of 3.
#
#
# BFGS
# Using this method did converge.  It had 7 iterations and 8 function evaluations.
#
#
# Powell
# Using this method did converge. It had 4 iterations and 93 iterations.
#
# Nelder-Mead
# Using this method did converge. It had 71 iterations and 133 function evaluations.
#
# Trust-constr
# Using this method did converge. It had the same iterations as it did function computations of 3.
#
#
# SLSQP
# Using this method did converge. It had 7 iterations and 8 function evaluations.
#
# COBYLA
# Using this method did converge. Optimization terminated successfully.
#
# TNC
# Using this method did converge. It had 3 iterations and 7 function evaluations.
#
# CG
# Using this method did converge. It had 2 iterations and 5 function evaluations.
#
# Dogleg
# Using this method did converge. It had 4 iterations and 5 function evaluations.
